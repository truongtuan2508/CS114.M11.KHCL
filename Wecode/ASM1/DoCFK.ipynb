# %%
from decimal import *
F = float(input())
C = Decimal(F-32) / Decimal(1.8)
K = Decimal(F-32) * Decimal(5/9) + Decimal(273.15)
getcontext().prec = 6
print(Decimal(C).normalize(),Decimal(K).normalize())
# Out:
# 472.6
# 244.778 517.928
