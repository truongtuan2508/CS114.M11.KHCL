# %%
n = int(input())
def Fibonacci(n):
    if n == 0:
        return 0
    elif n == 1 or n == 2:
        return 1
    else:
        return Fibonacci(n-1) + Fibonacci(n-2)
if n >= 1 and n <= 30:
  print(Fibonacci(n))
else:
  print("So", n, "khong nam trong khoang [1,30].")
# Out:
# 0
# So 0 khong nam trong khoang [1,30].
