# %%
from fractions import *
while True:
  n = int(input())
  if n >= 1 and n <= 100:
    break
for i in range(0,n):
  a,b = map(int,input().split())
  tmp = str(Fraction(a,b))
  for char in tmp:
    if char == '/':
      char = ' '
    print(char,end ="")
  print()
# Out:
# 5
# 6 8
# 3 4
# 3 7
# 3 7
# 5 10
# 1 2
# 10 5
# 2
# 25 100
# 1 4
