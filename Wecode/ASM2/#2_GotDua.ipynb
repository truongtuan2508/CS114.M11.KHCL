# %%
def check(n):
  for i in range(1,n-1):
    if n % i == 0:
      if (n//i) % 2 != 0:
        return False
  return True

n = int(input())
if check(n) == True:
  print('YES')
else:
  print('NO')
# Out:
# 8
# NO
