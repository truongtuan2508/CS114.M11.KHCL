# %%
str = input().lower()
for ch in str:
  if ch == 'a' or ch == 'y' or ch == 'i' or ch == 'u' or ch == 'e' or ch == 'o':
    ch = ''
  else:
    ch = '.' + ch
  print(ch,end ='')
# Out:
# pyThon
# .p.t.h.n
