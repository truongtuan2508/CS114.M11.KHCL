# %%
def count(k,g):
  result = 1
  temp = g
  while True:    
    if temp >= k:
      break  
    result = result + 1
    temp = temp + g
  return result

n, m, a = map(int, input().split())
print(int(count(n,a)) * int(count(m,a)))
# Out:
# 6 6 4
# 4
