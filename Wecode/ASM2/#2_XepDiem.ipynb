# %%
while True:
  testcase = int(input())
  if testcase >= 1 and testcase <= 100:
    break  

for i in range(testcase):
  n = int(input())
  k = 0
  while (True):
    if ((n + k) % 2 == 0) and ( (n + k) / 2 >= 2):
      print(k)
      break
    k = k + 1
# Out:
# 1
# 0
# 1
# 2
# 1
